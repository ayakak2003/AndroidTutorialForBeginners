# %% [markdown]
# <a href="https://colab.research.google.com/github/ayakak2003/AndroidTutorialForBeginners/blob/master/Aya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Load your dataset
df = pd.read_csv('/content/Salaries.csv')

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#    BasePay  OvertimePay   OtherPay  TotalPay  TotalPayBenefits  Year  \
# 0   167411            0  400184.25    567595         567595.43  2011
# 1   155966       245132  137811.38    538909         538909.28  2011
# 2   212739       106088   16452.60    335280         335279.91  2011
# 3    77916        56121  198306.90    332344         332343.61  2011
# 4   134402         9737  182234.59    326373         326373.19  2011
#
#           Agency
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# 4  San Francisco

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30278 entries, 0 to 30361
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                30278 non-null  int64
#  1   EmployeeName      30277 non-null  object
#  2   JobTitle          30277 non-null  object
#  3   BasePay           30278 non-null  float64
#  4   OvertimePay       30278 non-null  float64
#  5   OtherPay          30278 non-null  float64
#  6   TotalPay          30278 non-null  float64
#  7   TotalPayBenefits  30277 non-null  float64
#  8   Year              30277 non-null  float64
#  9   Agency            30277 non-null  object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#                  Id        BasePay    OvertimePay       OtherPay  Benefits  \
# count  30362.000000   30361.000000   30361.000000   30361.000000       0.0
# mean   15180.599993   74696.904818    5379.488587    4237.655611       NaN
# std     8764.742899   34452.939565   11261.837830    8532.614169       NaN
# min        1.000000       0.000000       0.000000       0.000000       NaN
# 25%     7590.250000   52076.660000       0.000000      46.000000       NaN
# 50%    15180.500000   68522.980000     349.900000    1280.000000       NaN
# 75%    22770.750000   97847.650000    5713.800000    5027.210000       NaN
# max    30361.000000  294580.020000  245131.880000  400184.250000       NaN
#
#             TotalPay  TotalPayBenefits     Year  Notes  Status
# count   30361.000000      30361.000000  30361.0    0.0     0.0
# mean    84314.049016      84314.049016   2011.0    NaN     NaN
# std     41207.910605      41207.910605      0.0    NaN     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30362 entries, 0 to 30361
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                30362 non-null  int64
#  1   EmployeeName      30361 non-null  object
#  2   JobTitle          30361 non-null  object
#  3   BasePay           30361 non-null  float64
#  4   OvertimePay       30361 non-null  float64
#  5   OtherPay          30361 non-null  float64
#  6   Benefits          0 non-null      float64
#  7   TotalPay          30361 non-null  float64
#  8   TotalPayBenefits  30361 non-null  float64
#  9   Year              30361 non-null  float64
#  10  Notes             0 non-null      float64
#  11  Agency            30361 non-null  object
#  12  Status            0 non-null      float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 3.0+ MB

# %%
num_rows, num_cols = df.shape

data_types = df.dtypes

missing_values = df.isnull().sum()
missing_values
# Out:
# Id                      0
# EmployeeName            1
# JobTitle                1
# BasePay                 0
# OvertimePay             0
# OtherPay                0
# Benefits            30278
# TotalPay                0
# TotalPayBenefits        1
# Year                    1
# Notes               30278
# Agency                  1
# Status              30278
# dtype: int64

# %%
mean_salary = df['TotalPay'].mean()
median_salary = df['TotalPay'].median()
mode_salary = df['TotalPay'].mode()[0]
min_salary = df['TotalPay'].min()
max_salary = df['TotalPay'].max()
salary_range = max_salary - min_salary
std_dev_salary = df['TotalPay'].std()

# %%
df.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []>

# %%
df.mean()
# Out:
# Id                  NaN
# EmployeeName        NaN
# JobTitle            NaN
# BasePay             NaN
# OvertimePay         NaN
# OtherPay            NaN
# Benefits            NaN
# TotalPay            NaN
# TotalPayBenefits    NaN
# Year                NaN
# Notes               NaN
# Agency              NaN
# Status              NaN
# dtype: object

# %%
df['TotalPay'].fillna(mean_salary, inplace=True)

# %%
import matplotlib.pyplot as plt

# Create a histogram to visualize the distribution of salaries
plt.hist(df['TotalPay'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# Create a pie chart to represent the proportion of employees in different departments
department_proportion = df['JobTitle'].value_counts().head(10)
plt.pie(department_proportion, labels=department_proportion.index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Employees in Different Departments')
plt.show()

# %%
# Group the data by department and calculate average salaries
average_salary_by_department = df.groupby('JobTitle')['TotalPay'].mean()
average_salary_by_department
# Out:
# JobTitle
# ACCOUNT CLERK                                     46552.406667
# ACCOUNTANT                                        58999.485000
# ACCOUNTANT INTERN                                 48457.076250
# ACUPUNCTURIST                                     67594.400000
# ADMINISTRATIVE ANALYST                            67824.311609
#                                                       ...
# WORKER'S COMPENSATION ADJUSTER                    73943.958095
# WORKER'S COMPENSATION SUPERVISOR I                91020.726000
# X-RAY LABORATORY AIDE                             56283.645000
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    53632.870000
# ZOO CURATOR                                       66686.560000
# Name: TotalPay, Length: 1026, dtype: float64

# %%
# Identify correlation between salary and another numerical column (let's say 'BasePay')
correlation = df['TotalPay'].corr(df['BasePay'])

# Plot a scatter plot to visualize the relationship
plt.scatter(df['BasePay'], df['TotalPay'], alpha=0.5)
plt.title('Scatter Plot - Salary vs BasePay')
plt.xlabel('BasePay')
plt.ylabel('TotalPay')
plt.show()

# %%
# Convert multiple columns to lowercase
columns_to_lower = ['EmployeeName', 'JobTitle', 'Agency']
df[columns_to_lower] = df[columns_to_lower].apply(lambda x: x.str.lower())

# %%
# Remove duplicates based on multiple columns (e.g., 'EmployeeName' and 'JobTitle')
df.drop_duplicates(subset=['EmployeeName', 'JobTitle'], inplace=True)

# %%
# Specify columns for which you want to replace empty cells
columns_to_fill = ['TotalPay', 'BasePay', 'OvertimePay','OtherPay']

# Calculate the median for the specified columns
median_values_subset = df[columns_to_fill].median()

# Replace empty cells in the specified columns with their respective median values
df[columns_to_fill] = df[columns_to_fill].fillna(median_values_subset)

# %%
# Remove multiple columns
columns_to_remove = ['Benefits','Notes', 'Status']
df.drop(columns=columns_to_remove, inplace=True)

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Year'].fillna(0, inplace=True)  # Replace NaN with 0 or another appropriate value
df['Year'] = df['Year'].astype(int)

# %%
# Round 'Year' column values and then convert to integer
# Round values in multiple columns and then convert to integers
columns_to_round = ['TotalPay', 'BasePay', 'OvertimePay']
df[columns_to_round] = df[columns_to_round].round().astype(int)

# %%
import matplotlib.pyplot as plt

# Create a histogram to visualize the distribution of salaries
plt.hist(df['TotalPay'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# Create a pie chart to represent the proportion of employees in different departments
department_proportion = df['JobTitle'].value_counts().head(10)
plt.pie(department_proportion, labels=department_proportion.index, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Employees in Different Departments')
plt.show()
